# %%
import string
import textcleaner as tc
import pandas
data=tc.document(r'C:\Users\My PC\Desktop\Hackathon\analysis.txt')
word = data.remove_stpwrds()
words=str(word)
final=words.split()
print(final)
# Out:
# ['I’m', '27', 'years', 'old', 'life', 'feels', 'like', 'waste', 'time.', 'I', 'purpose', 'motivation.', 'I’ve', 'diagnosed', 'depression', 'anxiety', 'I', 'think', 'I', 'might', 'mild', 'case', 'two,', 'I', 'don’t', 'know.', 'I’m', 'law', 'graduate', 'I', 'didn’t', 'get', 'impressive', 'grades', 'I', 'work', 'retail.', 'The', 'legal', 'field', 'incredibly', 'competitive', 'I', 'gave', 'up.', 'I', 'feel', 'empty', 'often', 'not.', 'I', 'don’t', 'really', 'friends', 'ever', 'relationship.', 'My', 'social', 'life', 'non', 'existent.', 'I’m', 'currently', 'studying', 'part', 'time', 'learning', 'code.', 'I', 'think', 'interesting', 'I', 'keep', 'finding', 'drifting', 'wondering', 'point?', 'I’m', 'always', 'trying', 'learn', 'things', '(guitar,', 'languages', 'etc)', 'never', 'truly', 'stick', 'out.', 'My', 'life', 'terribly', 'boring', 'I', 'don’t', 'energy', 'feel', 'positive', 'engage', 'people.', 'Everything', 'feels', 'pointless.', 'I', 'don’t', 'know', 'do.', 'I', 'live', 'life', '
# ...

# %%
import matplotlib.pyplot as plt
plt.hist(final,5, histtype='bar',
align='mid', color='c', label='Keyword Analysis',edgecolor='black')
plt.legend()
plt.title('Histogram of Keywords')
plt.show()
